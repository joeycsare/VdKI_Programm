# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import sklearn
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import load_sample_image # Laden Beispielbilder
china = load_sample_image("china.jpg") / 255 # Skalieren der Pixelintensitaet auf [0..1]
flower = load_sample_image("flower.jpg") / 255
images = np.array([china,flower])
batchsize, height, width, channels = images.shape

# %%
plt.imshow(china, cmap="gray") #zeichne die 2. Feature map des 1. Bildes

plt.show()

# %% [markdown]
# ### Filtererstellen

# %%
filters = np.zeros(shape=(7,7, channels, 2), dtype=np.float32) # 7x7 Filter
filters[:, 3, :, 0] =  1 #vertikale Linie
filters[3, :, :, 1] = 1 #horizontale Linie

outputs = tf.nn.conv2d(images, filters, strides=1, padding="SAME") # Schrittweite 1, zero-Padding

# %% [markdown]
# Wirkung horizontaler Filter

# %%
plt.imshow(outputs[0, :, :, 0], cmap="gray") #zeichne die 2. Feature map des 1. Bildes

plt.show()  # Ausgabe entstandner feature-map

# %% [markdown]
# Wirkung vertikaler Filter

# %%
plt.imshow(outputs[0, :, :, 1], cmap="gray") #zeichne die 2. Feature map des 1. Bildes

plt.show()  # Ausgabe entstandner feature-map

# %%
#conv = keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, padding="same", activation="relu") 
# erstellt Filter automatisch

# %% [markdown]
# Mnist fashion dataset laden, 28x28 Array Bilder, Pixelintensitäten von 0 bis 255

# %%
import tensorflow_datasets as tfds

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()
#dataset = tfds.load(name="fashion_mnist", batch_size=32, as_supervised=True)
#fashion_train, fashion_test = dataset["train"].prefetch(1), dataset["test"]

# %%
print('Dimensionen Trainingsdaten: ', train_images.shape) #Bilder als numpy-Arrays
print('Anzahl Trainingsdaten: ',len(train_labels))
print('Lables Trainingsdaten: ', train_labels) #Klassenbezeichnungen, als Ziffernarray
# Out:
# Dimensionen Trainingsdaten:  (60000, 28, 28)
# Anzahl Trainingsdaten:  60000
# Lables Trainingsdaten:  [9 0 0 ... 3 0 5]

# %%
print('Datentyp:',train_images.dtype)
# Out:
# Datentyp: uint8

# %% [markdown]
# Anzeigen eines Bildes der Trainingsdatenmenge

# %%
print('Dimensionen Testsdaten: ', test_images.shape) #Bilder als numpy-Arrays
print('Anzahl Testdaten: ',len(test_labels))
print('Lables Testdaten: ', test_labels) #Klassenbezeichnungen, als Ziffernarray
# Out:
# Dimensionen Testsdaten:  (10000, 28, 28)
# Anzahl Testdaten:  10000
# Lables Testdaten:  [9 2 1 ... 8 1 5]

# %%
digit=train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation="relu", padding="same",
                       input_shape=[28, 28, 1]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128, 3, activation="relu", padding="same"),
    keras.layers.Conv2D(128, 3, activation="relu", padding="same"),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(256, 3, activation="relu", padding="same"),
    keras.layers.Conv2D(256, 3, activation="relu", padding="same"),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation="softmax"),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        3200
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               295040
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,413,834
# Trainable params: 1,413,834
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Vorverarbeitung DAten

# %%
#train_images=train_images.reshape((60000,28*28)) # Umwandeln in 2D_Array 
train_images=train_images.astype('float32') / 255  # Umwandeln in float von uint8, auf Werte von 00..1 aus 0..255

# %%
#test_images=test_images.reshape((10000,28*28)) # Umwandeln in 2D_Array 
test_images=test_images.astype('float32') / 255  # Umwandeln in float von uint8, auf Werte von 00..1 aus 0..255

# %% [markdown]
# Kategorisierung Klassenbezeichnungen

# %%
from keras.utils.np_utils import to_categorical
train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)

# %% [markdown]
# Validierung mit Extra abgesplatener Validierungsmenge

# %%
images_val = train_images[:10000] #10000 Datensätze zurückhalten als Validierungdmenge
partial_images_val = train_images[50000:]
labels_val = train_labels[:10000] 
partial_labels_val = train_labels[50000:]

# %% [markdown]
# Vorbereitung Netz

# %%
model.compile(loss="sparse_categorical_crossentropy",
             optimizer="sgd",
             metrics=["accuracy"])

# %% [markdown]
# Trainieren

# %%
history=model.fit(train_images, train_labels, epochs=2)
# network_history=model.fit(partial_images_val,
#                           partial_labels_val, 
#                           epochs=20, 
#                           batch_size=128,
#                           validation_data=(images_val,labels_val))
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-be44e65a273f> in <module>
# ----> 1 history=model.fit(train_images, train_labels, epochs=2)
#       2 # network_history=model.fit(partial_images_val,
#       3 #                           partial_labels_val,
#       4 #                           epochs=20,
#       5 #                           batch_size=128,
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# ValueError: in user code:
#
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\training.py:855 train_function  *
#         return step_function(self, iterator)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\training.py:845 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\training.py:838 run_step  **
#         outputs = model.train_step(data)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\training.py:795 train_step
#         y_pred = self(x, training=True)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1013 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     D:\Programme\Python\Anaconda\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:230 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: : expected min_ndim=4, found ndim=3. Full shape received: (32, 28, 28)

# %%
class_names = ["T-shirt/top", "Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]

# %% [markdown]
# Testen

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('Korrektklasssifiziereungsrate Test:',test_acc)

# %%
#history_dict=network_history.history
history_dict=history.history
history_dict.keys()

# %% [markdown]
# history_dict=network_history.history
# history_dict.keys()

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo', 
        label='Verlust Training') # bo blauer punkt
plt.plot(epochs, val_loss_values, 'b',
        label='Verlust Validierung')
plt.title('Wert der Verlustfunktion Training / Validierung')
plt.xlabel('Epochen')
plt.ylabel('Wert der Verlustfunktion')
plt.legend()
plt.show()

# %% [markdown]
# ### Korrektklassifizierungsrate

# %%
plt.clf() #Zeichenbereich löschen
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

plt.plot(epochs, acc, 'ro', 
        label='Training') # bo blauer punkt
plt.plot(epochs, val_acc, 'r',
        label='Validierung')
plt.title('Korrektklassifizierungsrate Training / Validierung')
plt.xlabel('Epochen')
plt.ylabel('Korrektklassifizierungsrate')
plt.legend()
plt.show()
